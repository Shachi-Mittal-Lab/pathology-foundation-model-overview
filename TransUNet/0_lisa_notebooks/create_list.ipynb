# %%
import os

# %%
list_txt = r'E:\PROJ_DCIS\lists\lists_dcisHE_TU_pretrain_R50-ViT-B_16_skip3_epo150_bs8_224_4class\train.txt'
patches_dir = r'E:\PROJ_DCIS\training_patches\annotation_scheme-0\TEMP_half-patches'

names = []
for file in os.listdir(patches_dir):
    if file.endswith('.npz'):
        filename = os.path.splitext(file)[0]
        names.append(filename)

# %%
print(len(names))
print(names[0:10])
# Out:
# 7000
# ['102_A6.1_H&E_tile_y10094336_x10094336', '102_A6.1_H&E_tile_y10094336_x10563840', '102_A6.1_H&E_tile_y10094336_x10798592', '102_A6.1_H&E_tile_y10094336_x11033344', '102_A6.1_H&E_tile_y10094336_x11268096', '102_A6.1_H&E_tile_y10094336_x12911360', '102_A6.1_H&E_tile_y10094336_x13146112', '102_A6.1_H&E_tile_y10094336_x13850368', '102_A6.1_H&E_tile_y10094336_x14085120', '102_A6.1_H&E_tile_y10094336_x17606400']

# %%
with open(list_txt, "w", encoding="utf-8") as f:
    for name in names:
        f.write(name + "\n")
